# %% [markdown]
# <a href="https://colab.research.google.com/github/uwais47/python/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a DataFrame of GDP against Life expectancy at birth in 2010
import numpy as np
import pandas as pd
df=pd.DataFrame ( {
"country" : pd.categorical(["Algeria","Egypt","Libya" , "Morocco" , "Sudan"])
"GDP" : pd.categorical(["15200" , "12700" , "9600" , "8600" , "4300"])
})
# Out:
#   File "<ipython-input-12-11049d3c5f77>", line 5
#     "country" : pd.categorical(["Algeria" , "Egypt" , "Libya" , "Morocco" , "Sudan"])
#                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd # Import pandas for data analysis
import seaborn as sns # Import seaborn for visualisations
import matplotlib.pyplot as plt
df1 = pd.read_excel("Data-1-AQA.xlsx" , sheet_name = "Data")
df1.iloc[0 : 5 , [0, 1, 3,9, 19]]
# Out:
#    no  Country  population  GDP per capita (US$)  \
# 0   1  Algeria    41657488               15200.0
# 1   2    Egypt    99413317               12700.0
# 2   3    Libya     6754507                9600.0
# 3   4  Morocco    34314130                8600.0
# 4   5    Sudan    43120843                4300.0
#
#    Life expectancy at birth 2010
# 0                         74.676
# 1                         70.357
# 2                         71.643
# 3                         73.999
# 4                         62.620

# %%
# Create box plots of life expectancy in 2010, grouped by region.
fig = plt.figure()
sns.relplot(data=df1, y="Life expectancy at birth 2010", \
 x="GDP per capita (US$)", hue="physician density (physicians/1000 population)",aspect=2)
